# %%
from wann_genetic.tools import load_series_stats, mean_comparison
from util import accuracy_swarmplot
import pandas as pd

# %%
from IPython.display import set_matplotlib_formats
# %matplotlib inline
set_matplotlib_formats('svg')

# %% [markdown]
# # Results on Iris task using lognormal propability distributions to sample weights

# %%
def load_trial(t_dir):
    return load_series_stats(f"../data/iris_lognormal/{t_dir}")

# %%
trial_1 = load_trial('trial 1')
trial_2 = load_trial('trial 2')
df = pd.concat([trial_2, trial_1])
df = df.sort_values(by=['distribution/mean', 'distribution/sigma', 'seed'])

# %%
mu_df = df[df['distribution/sigma'] >= 1].copy()
mu_df['mean,sigma'] = mu_df.agg('{0[distribution/mean]},{0[distribution/sigma]:.0f}'.format, axis=1)

# %%
accuracy_swarmplot(data=mu_df, x="mean,sigma", xlabel='$\mu,\sigma$', old_metrics=True)

# %%
accuracy_swarmplot(data=mu_df, x="distribution/mean", xlabel='$\mu$', old_metrics=True)

# %%
accuracy_swarmplot(data=mu_df, x="distribution/sigma", xlabel='$\sigma$', old_metrics=True)

# %% [markdown]
# ## Test with smaller $\sigma$ and $\mu=0$

# %%
mu0_df = df[df['distribution/mean'] == 0]

# %%
accuracy_swarmplot(data=mu0_df, x="distribution/sigma", xlabel='$\sigma$', old_metrics=True)

# %%
print(series.hyperparam_table(tablefmt='grid'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ade6ec35529c> in <module>
# ----> 1 print(series.hyperparam_table(tablefmt='grid'))
#
# NameError: name 'series' is not defined
