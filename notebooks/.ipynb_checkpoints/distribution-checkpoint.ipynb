# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu = 0
sigma = 1

samples = np.random.lognormal(mu, sigma,1000)
x = np.linspace(np.min(samples), np.max(samples) +1, 1000)

normal = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2))
lognormal = 1/(sigma * x * np.sqrt(2 * np.pi)) * np.exp( - (np.log(x) - mu)**2 / (2 * sigma**2))

# %%
plt.hist(samples, bins=100, density=True)
plt.plot(x, lognormal, linewidth=2, color='r')
plt.show()
