# %% [markdown]
# # Influence of the initial population on the result of the experiment
#
# The initially generated population is certainly important for the course of the experiment. Since it is created randomly we need to asess how much of an influence it will have on the end result.
#
# In this experiment, three initial populations were created and then evolved using different post initialization seeds.

# %%
from wann_genetic.tools import ExperimentSeries
from util import accuracy_swarmplot

# %%
from IPython.display import set_matplotlib_formats
# %matplotlib inline
set_matplotlib_formats('svg')

# %%
data_dir = "../data/iris_init_pop/trial 3"
series = ExperimentSeries.from_spec_file(data_dir)
series.discover_data_dir()
df = series.assemble_stats()
series.var_names()
# Out:
# odict_keys(['initial_edge_prob', 'post_init_seed', 'population_seed'])

# %%
df['initial gene type'] = df.aggregate(lambda row: f"{row['initial_edge_prob/_name']}", axis=1)

# %%
accuracy_swarmplot(data=df, x="initial gene type", xlabel="Initialization of the population\n(empty or probability of an edge being enabled)")

# %% [markdown]
# ## Populations that have been initialized entirely disabled edges

# %%
selection = (df['initial_edge_prob/initial_genes'] != 'empty') & (df['initial_edge_prob/initial_enabled_edge_prob'] == 0)
patrial_df = df[selection]

# %%
accuracy_swarmplot(data=patrial_df, x='post_init_seed', xlabel='Seed used after initializing the population')

# %%
accuracy_swarmplot(data=patrial_df, x='population_seed', xlabel='Seed used to initialize the population')

# %% [markdown]
# ## Populations that have been initialized ~50% enabled edges

# %%
selection = (df['initial_edge_prob/initial_genes'] != 'empty') & (df['initial_edge_prob/initial_enabled_edge_prob'] == 0.5)
patrial_df = df[selection]

# %%
accuracy_swarmplot(data=patrial_df, x='post_init_seed', xlabel='Seed used after initializing the population')

# %%
accuracy_swarmplot(data=patrial_df, x='population_seed', xlabel='Seed used to initialize the population')

# %% [markdown]
# ## Populations that have been initialized with single individual

# %%
selection = (df['initial_edge_prob/initial_genes'] == 'empty')
patrial_df = df[selection]

# %%
accuracy_swarmplot(data=patrial_df, x='post_init_seed', xlabel='Seed used after initializing the population')

# %%
accuracy_swarmplot(data=patrial_df, x='population_seed', xlabel='Seed used to initialize the population')

# %% [markdown]
# ## Other hyerparameters

# %%
print(series.hyperparam_table(tablefmt='grid'))
# Out:
# WARNING:root:Key ('sampling', 'distribution') was not used.
# WARNING:root:Key ('sampling', 'lower_bound') was not used.
# WARNING:root:Key ('sampling', 'upper_bound') was not used.
# WARNING:root:Key ('sampling', 'mean') was not used.
# WARNING:root:Key ('sampling', 'sigma') was not used.
# WARNING:root:Key ('sampling', 'num_weight_samples_per_iteration') was not used.
# WARNING:root:Key ('task', 'test_portion') was not used.
# WARNING:root:Key ('task', 'sample_length') was not used.
# WARNING:root:Key ('task', 'num_categories') was not used.
# WARNING:root:Key ('population', 'initial_func') was not used.
# WARNING:root:Key ('population', 'enabled_activation_funcs') was not used.
# WARNING:root:Key ('selection', 'hof_metric') was not used.
# WARNING:root:Key ('mutation', 'new_edge', 'probability') was not used.
# WARNING:root:Key ('mutation', 'new_node', 'probability') was not used.
# WARNING:root:Key ('mutation', 'reenable_edge', 'probability') was not used.
# WARNING:root:Key ('mutation', 'change_activation', 'probability') was not used.
# WARNING:root:Key ('mutation', 'change_edge_sign', 'probability') was not used.
# WARNING:root:Key ('mutation', 'new_recurrent_edge', 'probability') was not used.
# WARNING:root:Key ('mutation', 'new_recurrent_edge', 'strategy') was not used.
# +----------------------------------------------------+--------------------------------------+
# | Parameter                                          | Value                                |
# +====================================================+======================================+
# | Population size                                    | 100                                  |
# +----------------------------------------------------+--------------------------------------+
# | Number of generations                              | 200                                  |
# +----------------------------------------------------+--------------------------------------+
# | Initial population                                 | fully connected                      |
# |                                                    | (edges have 5% chance of             |
# |                                                    | being enabled)                       |
# +----------------------------------------------------+--------------------------------------+
# | Size of the hall of fame                           | 10                                   |
# +----------------------------------------------------+--------------------------------------+
# | Edge signs enabled                                 | False                                |
# +----------------------------------------------------+--------------------------------------+
# | Objectives                                         | Minimize the min log_loss,           |
# |                                                    |                                      |
# |                                                    | minimize the mean log_loss,          |
# |                                                    |                                      |
# |                                                    | minimize the number of hidden nodes. |
# +----------------------------------------------------+--------------------------------------+
# | Elite ratio                                        | 10%                                  |
# | (ratio of individuals to survive without mutation) |                                      |
# +----------------------------------------------------+--------------------------------------+
# | Culling ratio                                      | 20%                                  |
# | (ratio of individuals to exclude from selection)   |                                      |
# +----------------------------------------------------+--------------------------------------+
# | Number of individuals in a tournament              | 5                                    |
# +----------------------------------------------------+--------------------------------------+
# | New edge mutation strategy                         | layer_agnostic                       |
# +----------------------------------------------------+--------------------------------------+
# | Number of weights per generation                   | 1                                    |
# +----------------------------------------------------+--------------------------------------+
# | Number of training samples per generation          | all                                  |
# +----------------------------------------------------+--------------------------------------+
# | Number of evaluation iterations required           | 20                                   |
# | to enter hall of fame (if to few, individual will  |                                      |
# | be more thoroughly evaluated)                      |                                      |
# +----------------------------------------------------+--------------------------------------+
